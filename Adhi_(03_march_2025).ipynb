# %% [markdown]
# <a href="https://colab.research.google.com/github/AdieshwarReddy/2311cs020426-AL-ML-daily-programs-/blob/main/Adhi_(03_march_2025).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 74.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 126.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.6 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,roc_auc_score,confusion_matrix

import streamlit as st

# %%
data=pd.read_csv("/content/online_shoppers_intention.csv")

# %%
data.head()
# Out:
#    Administrative  Administrative_Duration  Informational  ...  TrafficType        VisitorType  Weekend
# 0              26              1861.127910              2  ...          2.0        New_Visitor    False
# 1              25              1022.876853             19  ...         19.0  Returning_Visitor     True
# 2              20               623.214396              9  ...          3.0  Returning_Visitor    False
# 3              15               705.246011             21  ...         19.0  Returning_Visitor    False
# 4              15              1104.862443             14  ...          5.0        New_Visitor     True
#
# [5 rows x 17 columns]

# %%
data.tail()
# Out:
#        Administrative  Administrative_Duration  ...        VisitorType  Weekend
# 18228               1              1320.997610  ...  Returning_Visitor     True
# 18229               1               254.767993  ...              Other     True
# 18230               6              2146.398608  ...        New_Visitor     True
# 18231              20               318.707812  ...              Other    False
# 18232              23              1442.977245  ...                NaN      NaN
#
# [5 rows x 17 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18233 entries, 0 to 18232
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           18233 non-null  int64
#  1   Administrative_Duration  18233 non-null  float64
#  2   Informational            18233 non-null  int64
#  3   Informational_Duration   18233 non-null  float64
#  4   ProductRelated           18233 non-null  int64
#  5   ProductRelated_Duration  18233 non-null  float64
#  6   BounceRates              18233 non-null  float64
#  7   ExitRates                18232 non-null  float64
#  8   PageValues               18232 non-null  float64
#  9   SpecialDay               18232 non-null  float64
#  10  Month                    18232 non-null  object
#  11  OperatingSystems         18232 non-null  float64
#  12  Browser                  18232 non-null  float64
#  13  Region                   18232 non-null  float64
# ...

# %%
data.describe()
# Out:
#        Administrative  Administrative_Duration  ...        Region   TrafficType
# count    18233.000000             18233.000000  ...  18232.000000  18232.000000
# mean        13.451763              1693.765577  ...      4.980309     10.501591
# std          8.064985               983.097463  ...      2.579544      5.787575
# min          0.000000                 0.297493  ...      1.000000      1.000000
# 25%          6.000000               840.616175  ...      3.000000      5.000000
# 50%         13.000000              1676.834343  ...      5.000000     11.000000
# 75%         20.000000              2545.137999  ...      7.000000     16.000000
# max         27.000000              3398.329769  ...      9.000000     20.000000
#
# [8 rows x 14 columns]

# %%
data.shape
# Out:
# (18233, 17)

# %%
data.isnull().sum()
# Out:
# Administrative             0
# Administrative_Duration    0
# Informational              0
# Informational_Duration     0
# ProductRelated             0
# ProductRelated_Duration    0
# BounceRates                0
# ExitRates                  1
# PageValues                 1
# SpecialDay                 1
# Month                      1
# OperatingSystems           1
# Browser                    1
# Region                     1
# TrafficType                1
# VisitorType                1
# Weekend                    1
# dtype: int64

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18228    False
# 18229    False
# 18230    False
# 18231    False
# 18232    False
# Length: 18233, dtype: bool

# %%
len(data[data.duplicated()])
# Out:
# 0

# %%
data.columns()
# Out:
# Index(['Administrative', 'Administrative_Duration', 'Informational',
#        'Informational_Duration', 'ProductRelated', 'ProductRelated_Duration',
#        'BounceRates', 'ExitRates', 'PageValues', 'SpecialDay', 'Month',
#        'OperatingSystems', 'Browser', 'Region', 'TrafficType', 'VisitorType',
#        'Weekend'],
#       dtype='object')

# %%
for column in data.columns:
  print(data[column].value_counts())
# Out:
# Administrative
# 6     686
# 24    678
# 22    678
# 16    674
# 11    672
# 2     671
# 8     668
# 10    667
# 14    666
# 1     663
# 7     657
# 20    653
# 5     652
# 25    649
# 23    647
# 0     645
# 12    644
# 18    644
# 9     644
# 13    641
# 17    638
# 26    637
# 19    636
# 3     635
# 4     628
# 21    624
# 15    618
# 27    618
# Name: count, dtype: int64
# Administrative_Duration
# 1861.127910    1
# 2433.758545    1
# 3265.600677    1
# 474.105623     1
# 1638.752880    1
#               ..
# 112.049379     1
# 298.422413     1
# 4.127817       1
# 999.031842     1
# 1442.977245    1
# Name: count, Length: 18233, dtype: int64
# Informational
# 14    790
# 12    769
# 15    765
# 18    760
# 4     759
# 13    751
# 9     750
# 10    748
# 5     747
# 20    744
# 23    742
# 2     739
# 11    738
# 19    725
# 1     723
# 6     720
# 17    718
# 22    718
# 8     715
# 0     713
# 16    701
# 3     696
# 7     692
# 24    671
# 21    639
# ...
