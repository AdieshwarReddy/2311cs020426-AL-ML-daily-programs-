# %% [markdown]
# <a href="https://colab.research.google.com/github/AdieshwarReddy/2311cs020426-AL-ML-daily-programs-/blob/main/05_02_2025(426)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula as smf
import numpy as np

# %%
cars =pd.read_csv(r"/content/sample_data/Cars.csv")
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 76    False
# 77    False
# 78    False
# 79    False
# 80    False
# Length: 81, dtype: bool

# %%
cars.tail(54)
# Out:
#      HP        MPG  VOL          SP         WT
# 27   92  38.411003   99  119.105055  32.835069
# 28   52  43.469434  104   99.564907  34.483207
# 29  103  35.404192  107  121.840817  35.549360
# 30   84  39.431235  114  113.484609  37.042350
# 31   84  39.431235  101  112.288996  33.234361
# 32  102  36.285456   97  119.921115  31.380041
# 33  102  36.285456  113  121.392639  37.573290
# 34   81  39.531633  101  111.288996  32.701644
# 35   90  37.958743   98  115.013085  31.911223
# 36   90  37.958743   88  114.093383  28.754000
# 37  102  34.070668   86  116.909442  27.879915
# 38  102  34.070668   86  116.909442  28.630502
# 39  130  31.014131   92  128.461264  30.115434
# 40   95  35.152727  113  116.392639  37.392524
# 41   95  35.152727  106  115.748847  35.027176
# 42  102  34.070668   92  117.461264  30.527427
# 43   95  35.152727   88  114.093383  28.343976
# 44   93  35.643558  102  114.380966  33.078632
# 45  100  34.561499   99  117.105055  32.621916
# ...

# %%
cars.tail()
# Out:
#      HP        MPG  VOL          SP         WT
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615

# %%
cars.shape
# Out:
# (81, 5)

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
cars['SP'].duplicated()
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
#       ...
# 76    False
# 77    False
# 78    False
# 79    False
# 80    False
# Name: SP, Length: 81, dtype: bool

# %% [markdown]
# #EDA

# %%
sns.displot(cars['HP'])
plt.show()

# %%
sns.boxplot(cars['HP'])
plt.show()
