# %% [markdown]
# <a href="https://colab.research.google.com/github/AdieshwarReddy/2311cs020426-AL-ML-daily-programs-/blob/main/Adhi_(Excelr_project).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 26.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 22.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 3.7 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,roc_auc_score,confusion_matrix

import streamlit as st

# %%
data=pd.read_csv("/content/drive/MyDrive/Heart_Disease_Dataset.csv")

# %%
data.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0          Yes  14.96     Yes             Yes     No               7
# 1          Yes  36.93     Yes             Yes     No               3
# 2           No  18.70     Yes              No    Yes              26
# 3          Yes  31.43     Yes             Yes    Yes              24
# 4          Yes  75.64      No              No    Yes               2
#
#    MentalHealth DiffWalking     Sex AgeCategory  \
# 0             6         Yes  Female       25-29
# 1            10          No  Female       30-34
# 2            15          No    Male       70-74
# 3            20          No  Female       40-44
# 4            29          No    Male       35-39
#
#                              Race                 Diabetic PhysicalActivity  \
# 0                           White                      Yes              Yes
# 1                        Hispanic  No, borderline diabetes              Yes
# ...

# %%
data.tail()
# Out:
#        Administrative  Administrative_Duration  Informational  \
# 97995               1              2093.900453             20
# 97996              27              3392.587490             22
# 97997               6               236.829385             20
# 97998              12              2212.771577             16
# 97999               5              3336.834751             22
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 97995              438.993425             676             63653.493703
# 97996              910.620855              75             17831.242600
# 97997             2213.647664             118             34341.761329
# 97998             2252.237564             483             21171.811242
# 97999              887.764936             379             32484.619848
#
#        BounceRates  ExitRates  PageValues  SpecialDay Month  OperatingSystems  \
# 97995     0.049749   0.068814   26.230931    0.683104   Jul                 2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100201 entries, 0 to 100200
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      100201 non-null  object
#  1   BMI               100201 non-null  float64
#  2   Smoking           100201 non-null  object
#  3   AlcoholDrinking   100201 non-null  object
#  4   Stroke            100201 non-null  object
#  5   PhysicalHealth    100201 non-null  int64
#  6   MentalHealth      100201 non-null  int64
#  7   DiffWalking       100201 non-null  object
#  8   Sex               100201 non-null  object
#  9   AgeCategory       100201 non-null  object
#  10  Race              100201 non-null  object
#  11  Diabetic          100201 non-null  object
#  12  PhysicalActivity  100201 non-null  object
#  13  GenHealth         100201 non-null  object
#  14  SleepTime         100201 non-null  float64
#  15  Asthma            100201 non-null  object
# ...

# %%
data.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  100201.000000   100201.000000  100201.000000  100201.000000
# mean       53.373302       14.503937      14.498239      12.490389
# std        23.878712        8.640423       8.658639       6.632122
# min        12.020000        0.000000       0.000000       1.000000
# 25%        32.760000        7.000000       7.000000       6.700000
# 50%        53.380000       14.000000      15.000000      12.500000
# 75%        73.950000       22.000000      22.000000      18.200000
# max        94.850000       29.000000      29.000000      24.000000

# %%
data.shape
# Out:
# (100201, 18)

# %%
data.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 100196    False
# 100197    False
# 100198    False
# 100199    False
# 100200    False
# Length: 100201, dtype: bool

# %%
len(data[data.duplicated()])
# Out:
# 0

# %%
data.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
for column in data.columns:
  print(data[column].value_counts())
# Out:
# HeartDisease
# Yes    50134
# No     50067
# Name: count, dtype: int64
# BMI
# 56.38    26
# 91.47    26
# 27.95    26
# 88.49    26
# 66.39    25
#          ..
# 23.75     3
# 29.15     3
# 65.14     3
# 34.33     2
# 91.36     2
# Name: count, Length: 8284, dtype: int64
# Smoking
# Yes    50445
# No     49756
# Name: count, dtype: int64
# AlcoholDrinking
# Yes    50435
# No     49766
# Name: count, dtype: int64
# Stroke
# Yes    50265
# No     49936
# Name: count, dtype: int64
# PhysicalHealth
# 8     3430
# 20    3401
# 9     3395
# 16    3392
# 19    3386
# 13    3385
# 12    3377
# 26    3369
# 29    3363
# 15    3355
# 23    3354
# 22    3347
# 28    3345
# 14    3343
# 2     3341
# 1     3337
# 10    3334
# 11    3332
# 6     3329
# 0     3328
# 17    3327
# 7     3323
# 24    3316
# 5     3305
# 18    3301
# 3     3287
# 21    3285
# 27    3277
# 25    3270
# 4     3267
# Name: count, dtype: int64
# MentalHealth
# 27    3442
# 16    3442
# 13    3419
# 5     3403
# ...

# %%
binary_columns=["Smoking","AlcoholDrinking","Stroke","DiffWalking",'PhysicalActivity',"Asthma",'KidneyDisease', 'SkinCancer']

# %%
for col in binary_columns:
    data[col]=data[col].map({'Yes':1,"No":0})

# %%
binary_columns
# Out:
# ['Smoking',
#  'AlcoholDrinking',
#  'Stroke',
#  'DiffWalking',
#  'PhysicalActivity',
#  'Asthma',
#  'KidneyDisease',
#  'SkinCancer']

# %%
data.head()
# Out:
#   HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0          Yes  14.96      NaN              NaN     NaN               7
# 1          Yes  36.93      NaN              NaN     NaN               3
# 2           No  18.70      NaN              NaN     NaN              26
# 3          Yes  31.43      NaN              NaN     NaN              24
# 4          Yes  75.64      NaN              NaN     NaN               2
#
#    MentalHealth  DiffWalking     Sex AgeCategory  \
# 0             6          NaN  Female       25-29
# 1            10          NaN  Female       30-34
# 2            15          NaN    Male       70-74
# 3            20          NaN  Female       40-44
# 4            29          NaN    Male       35-39
#
#                              Race                 Diabetic  PhysicalActivity  \
# 0                           White                      Yes               NaN
# 1                        Hispanic  No, borderline diabetes               NaN
# ...

# %%
data=pd.get_dummies(data,columns=["Sex","AgeCategory","Race","GenHealth"],drop_first=True)

# %%
data.head()
# Out:
#   HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0          Yes  14.96      NaN              NaN     NaN               7
# 1          Yes  36.93      NaN              NaN     NaN               3
# 2           No  18.70      NaN              NaN     NaN              26
# 3          Yes  31.43      NaN              NaN     NaN              24
# 4          Yes  75.64      NaN              NaN     NaN               2
#
#    MentalHealth  DiffWalking                 Diabetic  PhysicalActivity  ...  \
# 0             6          NaN                      Yes               NaN  ...
# 1            10          NaN  No, borderline diabetes               NaN  ...
# 2            15          NaN                       No               NaN  ...
# 3            20          NaN  No, borderline diabetes               NaN  ...
# 4            29          NaN                       No               NaN  ...
#
# ...

# %%
data.tail()
# Out:
#        HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 100196           No  48.02      NaN              NaN     NaN              13
# 100197          Yes  82.88      NaN              NaN     NaN              29
# 100198           No  39.46      NaN              NaN     NaN              23
# 100199           No  46.25      NaN              NaN     NaN               9
# 100200           No  39.26      NaN              NaN     NaN              10
#
#         MentalHealth  DiffWalking                 Diabetic  PhysicalActivity  \
# 100196            17          NaN  No, borderline diabetes               NaN
# 100197            23          NaN  No, borderline diabetes               NaN
# 100198             6          NaN                      Yes               NaN
# 100199            14          NaN                       No               NaN
# 100200             5          NaN  No, borderline diabetes               NaN
#
# ...

# %%
data.isnull().sum()
# Out:
# HeartDisease                    0
# BMI                             0
# Smoking                    100201
# AlcoholDrinking            100201
# Stroke                     100201
# PhysicalHealth                  0
# MentalHealth                    0
# DiffWalking                100201
# Diabetic                        0
# PhysicalActivity           100201
# SleepTime                       0
# Asthma                     100201
# KidneyDisease              100201
# SkinCancer                 100201
# Sex_Male                        0
# AgeCategory_25-29               0
# AgeCategory_30-34               0
# AgeCategory_35-39               0
# AgeCategory_40-44               0
# AgeCategory_45-49               0
# AgeCategory_50-54               0
# AgeCategory_55-59               0
# AgeCategory_60-64               0
# AgeCategory_65-69               0
# AgeCategory_70-74               0
# AgeCategory_75-79               0
# AgeCategory_80 or older         0
# ...

# %%
x=data.drop("HeartDisease",axis=1)
y=data["HeartDisease"].map({'Yes':1,"No":0})

# %%
# In cell ipython-input-26-436a975d142b:
x = data.drop("HeartDisease", axis=1)
y = data["HeartDisease"].map({'Yes':1, 'No':0})

# In cell ipython-input-28-436a975d142b:
# Change 'X' to 'x' to match the variable name where the features are stored
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
clf=DecisionTreeClassifier(max_depth=5,criterion='gini',random_state=42)
clf.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-837f6f61c03c> in <cell line: 0>()
#       1 clf=DecisionTreeClassifier(max_depth=5,criterion='gini',random_state=42)
# ----> 2 clf.fit(X_train,y_train)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#    1022         """
#    1023
# -> 1024         super()._fit(
#    1025             X,
#    1026             y,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in _fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     250             )
# ...
